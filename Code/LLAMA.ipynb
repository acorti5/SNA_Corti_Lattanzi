# %% [markdown]
# # **SETTING THE LLM**

# %%
# %%capture
# installing libraries
# !pip install transformers
# !pip install torch

# %%
# logging in the model's website
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) y
# Token is valid (permission: write).
# The token `key` has been saved to /root/.cache/huggingface/stored_tokens
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.
# Token has not been saved to git credential helper.
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `key`

# %%
# loading data to be computed

import pandas as pd
import csv
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')

input_file = r'/content/gdrive/MyDrive/dati_sna/submissions_decimato_2022.csv'

# loading sumbissions into a list of authors and titles
authors = []
titles = []
ids=[]
with open(input_file, mode='r') as file:
    csvreader = csv.reader(file)
    next(csvreader) # skipping first row
    for row in csvreader:
        # discarding deleted users
        if row[0] != 'u/[deleted]':
            author, sub_id , title, score , created= row
            authors.append(row[0])
            ids.append(row[1])
            titles.append(row[2])
if len(authors) != len(titles):
    print("error, authors and titles are not the same length")

print(len(titles), "titles to classify")
# Out:
# Mounted at /content/gdrive
# 84741 titles to classify

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load model directly
tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-1B-Instruct")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
# move model on GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# check if the model is on the GPU (cuda:0 is good)
print(next(model.parameters()).device)
# Out:
# cuda:0

# %%
#Splitting of the data in order to use free colab

def split_list_equal(lst):
    n = len(lst)
    return lst[:n//3], lst[n//3:2*n//3], lst[2*n//3:]

titles1, titles2, titles3 = split_list_equal(titles)
authors1, authors2, authors3 = split_list_equal(authors)
ids1, ids2, ids3 = split_list_equal(ids)

# %% [markdown]
# # **VEGETARIAN/OMNIVOROUS**

# %% [markdown]
# ## SPLIT 1

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles1
authors=authors1
ids=ids1

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: vegetarian, omnivorous:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### omnivorous\n[Homemade] Jalapeno-Ghost Pepper Mac and Cheese with Pulled Pork #### omnivorous\n[homemade] steak sandwiches #### omnivorous\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### vegetarian\n[Homemade] crispy gnocchi & veg, in a spinach, leek, garlic and harissa sauce. Topped with (not homemade) beetroot falafel. #### vegetarian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 5.37 seconds
# Estimated time for all batches: 3035.80 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['[non', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'meat-based', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', '0vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'meat', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', '4-Ingredient', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', '[Not', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'meat', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'carnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegan', 'carnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', '3-tiered', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'meat,', 'omnivorous', 'omnivorous', 'omnivorous', '[Omn', 'vegetarian', 'vegetarian', 'Vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', '[vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'non-veget', 'omnivorous', 'vegetarian', 'omnivorous', '[Not', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', '[omn', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'o ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/veg_titles_2022_split_1.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "vegetarian" or element2 == "omnivorous":
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 94.48437002159521 %

# %% [markdown]
# ## SPLIT 2

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles2
authors=authors2
ids=ids2

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: vegetarian, omnivorous:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### omnivorous\n[Homemade] Jalapeno-Ghost Pepper Mac and Cheese with Pulled Pork #### omnivorous\n[homemade] steak sandwiches #### omnivorous\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### vegetarian\n[Homemade] crispy gnocchi & veg, in a spinach, leek, garlic and harissa sauce. Topped with (not homemade) beetroot falafel. #### vegetarian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 6.23 seconds
# Estimated time for all batches: 3518.92 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'meat', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', '[vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'fish', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', '5', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', '[homemade', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', '[Not]', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', '[Omn', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', '**omn', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'meat', 'omnivorous', 'vegetarian', 'vegetarian', '[Not', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'veggie', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'meat', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'iced', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', '[vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'om ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/veg_titles_2022_split_2.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "vegetarian" or element2 == "omnivorous":
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 94.20115410486069 %

# %% [markdown]
# ## SPLIT 3

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles3
authors=authors3
ids=ids3

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: vegetarian, omnivorous:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### omnivorous\n[Homemade] Jalapeno-Ghost Pepper Mac and Cheese with Pulled Pork #### omnivorous\n[homemade] steak sandwiches #### omnivorous\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### vegetarian\n[Homemade] crispy gnocchi & veg, in a spinach, leek, garlic and harissa sauce. Topped with (not homemade) beetroot falafel. #### vegetarian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 4.72 seconds
# Estimated time for all batches: 2665.05 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['omnivorous', 'omnivorous', 'omnivorous', '[vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'carnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', '[not', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'Vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', '[vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'meat', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', '[not', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'meat/om', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', '[vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', '[vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', '4', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'carnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'meat', 'vegetarian', 'vegetarian', 'vegetarian', '#', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', '#', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', '[non', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', 'iced', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', 'omnivorous', '#', 'vegetarian', 'meat', 'vegetarian', 'omnivorous', 'omnivorous', 'vegetarian', 'vegetarian', 'vegetarian', 'vegetarian', '[no', 'vegetarian', '[not', 'vegetarian', 'omnivorous', 'vegetarian', 'omnivorous', 'vegetarian', 'vegetarian', ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/veg_titles_2022_split_3.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "vegetarian" or element2 == "omnivorous":
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")

# %% [markdown]
# ## Split Combining

# %%
import pandas as pd

# Percorsi dei file CSV
dati_sna_path = "/content/gdrive/MyDrive/dati_sna/"
file_names = [
    "veg_titles_2022_split_1.csv",
    "veg_titles_2022_split_2.csv",
    "veg_titles_2022_split_3.csv"
]

# Leggi e unisci i file
combined_df = pd.concat([pd.read_csv(dati_sna_path + file) for file in file_names])

# Salva il file unito
output_file = dati_sna_path + "veg_titles_2022.csv"
combined_df.to_csv(output_file, index=False)

print(f"File unito salvato in: {output_file}")

# %% [markdown]
# # **SWEET/SAVORY**

# %% [markdown]
# ## SPLIT 1

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles1
authors=authors1
ids=ids1

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: sweet, savory:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### sweet\n[homemade] Chili #### savory\n[homemade] steak sandwiches #### savory\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### savory\n[I ATE] Red velvet black forest cake and lemon custard filled profiteroles with craquelin #### sweet\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 4.33 seconds
# Estimated time for all batches: 2448.26 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', '[homemade', 'Savory', 'savory', 'savory', 'sweet', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'sweet', 'savory', 'savory', 'savory', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'sweet', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'sweet', 'savory', 'sweet', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'sweet', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', '[sav', 'Savory', 'Savory', 'savory', 'savory', '[savour', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'sweet', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'sweet', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'sweet', 'savory', '[homemade', 'savory', 'sweet', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'sweet', 'savory', 'savory', 'sweet', 'sweet', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'sweet', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', "I'm", 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', '#', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', '[sav', 'Savory', 'sweet', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savor ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/sweet_titles_2022_split_1.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "sweet" or element2 == "savory" or element2=="Savory" or element2== "Sweet": #be careful for the capital
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 96.56246681063476 %

# %% [markdown]
# ## SPLIT 2

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles2
authors=authors2
ids=ids2

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: sweet, savory:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### sweet\n[homemade] Chili #### savory\n[homemade] steak sandwiches #### savory\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### savory\n[I ATE] Red velvet black forest cake and lemon custard filled profiteroles with craquelin #### sweet\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 5.77 seconds
# Estimated time for all batches: 3258.44 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'sweet', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'സ', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'sweet', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', '[sushi', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', '[homemade', 'sweet', '[homemade', 'savory', 'Savory', 'Savory', '[I', 'savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', '**s**', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'sweet', 'savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'sweet', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'Savory', '[homemade', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', '[savour', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'ouch.', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'scrambled', 'savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', '1.5', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', '[homemade', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'sweet', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'sweet', 'Savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/sweet_titles_2022_split_2.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "sweet" or element2 == "savory" or element2=="Savory":
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 96.20136651679825 %

# %% [markdown]
# ## SPLIT 3

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles3
authors=authors3
ids=ids3

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into: sweet, savory:\n\nMaryland style Crab Cakes with clarified butter and lemon. [Homemade] #### sweet\n[homemade] Chili #### savory\n[homemade] steak sandwiches #### savory\n[Homemade] Vegetable Pasta Salad with Red Wine Vinegar Vinaigrette #### savory\n[I ATE] Red velvet black forest cake and lemon custard filled profiteroles with craquelin #### sweet\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 4.99 seconds
# Estimated time for all batches: 2820.27 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['[sav', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'savory', 'savory', 'SAVORY', 'savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'sweet', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', '#', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', '[homemade', '[homemade', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', '[homemade', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'sweet', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'savory', 'Savory', '5', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savoury', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'savory', 'sweet', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', '[homemade', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'sweet', 'savory', '[savor', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'savory', 'Savory', 'savory', 'sweet', '[homemade', 'savory', 'Savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'savory', 'Savory', '0', 'savory', 'savory', 'Savory', 'savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', 'savory', 'sweet', 'sweet', '1/4', 'Savory', 'savory', 'sweet', 'Savory', 'sweet', 'sweet', 'sweet', 'savory', '3rd', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'Not', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'sweet', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'savory', 'Savory', 'sweet', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'sweet', 'sweet', 'savory', 'Savory', '[homemade', 'Savory', 'sweet', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'sweet', 'Savory', 'Savory', '[sweet]', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'sweet', 'Savory', 'savory', 'savory', 'savory', '5', 'savory', 'savory', 'savory', 'Savory', 'Savory', 'Savory', 'savory', 'sweet', 'Savory', 'Savory', 'savory', '(The', 'Savory', 'spicy', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'savory', 'savory', 'savory', 'savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'savory', 'Savory', 'Savory', 'Savory', 'Savory', 'savory', 'Savory', 'Savory', 'sav ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/sweet_titles_2022_split_3.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == "sweet" or element2 == "savory" or element2== "Savory":
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 96.34651467412468 %

# %% [markdown]
# ## Split Combining

# %%
import pandas as pd

# Percorsi dei file CSV
dati_sna_path = "/content/gdrive/MyDrive/dati_sna/"
file_names = [
    "sweet_titles_2022_split_1.csv",
    "sweet_titles_2022_split_2.csv",
    "sweet_titles_2022_split_3.csv"
]

# Leggi e unisci i file
combined_df = pd.concat([pd.read_csv(dati_sna_path + file) for file in file_names])

# Salva il file unito
output_file = dati_sna_path + "sweet_titles_2022.csv"
combined_df.to_csv(output_file, index=False)

print(f"File unito salvato in: {output_file}")
# Out:
# File unito salvato in: /content/gdrive/MyDrive/dati_sna/sweet_titles_2022.csv

# %% [markdown]
# # **I ATE-HOMEMADE-PRO/CHEF**

# %%
# loading data to be computed

import pandas as pd
import csv
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')

input_file = r'/content/gdrive/MyDrive/dati_sna/submissions_decimato_2022.csv'

# loading sumbissions into a list of authors and titles
authors = []
titles = []
ids=[]
with open(input_file, mode='r') as file:
    csvreader = csv.reader(file)
    next(csvreader) # skipping first row
    for row in csvreader:
        # discarding deleted users
        if row[0] != 'u/[deleted]':
            author, sub_id , title, score , created= row
            authors.append(row[0])
            ids.append(row[1])
            titles.append(row[2])
if len(authors) != len(titles):
    print("error, authors and titles are not the same length")

print(len(titles), "titles to classify")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 84741 titles to classify

# %%
import re

def classify_titles(titles):
    classifications = []
    for title in titles:
        lower_title = title.lower()
        if re.search(r'\b(i ate|ate)\b', lower_title):
            classifications.append(0)
        elif re.search(r'\b(homemade)\b', lower_title):
            classifications.append(1)
        elif re.search(r'\b(pro|chef)\b', lower_title):
            classifications.append(2)
        else:
            classifications.append("UNKNOWN")
    return classifications

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = classify_titles(titles)
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/tag_titles_2022.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
        if element2 == 0 or element2 == 1 or element2== 2:
            i+=1
print("percentage of good classification:",i/len(titles)*100,"%")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# percentage of good classification: 99.96341794408846 %

# %% [markdown]
# # ETHNIC CLASSIFICATION

# %% [markdown]
# ## SPLIT 1

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles1
authors=authors1
ids=ids1

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into the most probable cuisine ethnicity: Italian, American, Mexican, French, Chinese, Indian, Japanese, Middle Eastern, etc.\n\n[homemade] hummus I made today #### Middle Eastern\n[Homemade] Beef Shoyu Ramen #### Japanese\n[homemade] curry chicken, rice, & naan #### Indian\n[homemade] Chicken tacos and guacamole #### Mexican\n[Homemade] bacon and artichoke hearts pizza #### Italian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 4.73 seconds
# Estimated time for all batches: 2671.32 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['American', 'American', 'Italian', 'French', 'American', 'American', '[American]', 'Alaskan', 'American', 'French', 'American', 'American', 'Mexican', 'American', 'Iranian', 'Italian', 'Chinese', 'American', 'French', 'Chinese', 'British', 'American', 'American', 'Chinese', 'American', 'British', 'American', 'American', 'Chinese', 'Italian', 'American', 'American', 'Mexican', 'Chinese', 'American', 'American', 'American', 'Greek', '-', 'French', 'American', 'American', 'American', 'French', 'Chinese', '[Chinese]', '[homemade', 'Italian', 'American', 'Southern', 'Italian', 'French', 'American', 'Chinese', 'Chinese', 'American', 'Chinese', 'American', 'American', 'American', 'American', 'Chinese', 'American', 'American', 'American', 'Chinese', 'American', 'French', 'Chinese', 'Chinese', 'American', 'Indian', 'Chinese', 'Chinese', 'Chinese', 'Mexican', 'Chinese', 'Chinese', 'American', 'French', 'American', '(no', '-', 'American', 'American', 'Chinese', 'French', 'American', '(Note:', 'French', 'Chinese', 'American', 'American', 'American', 'American', 'Middle', 'American', 'American', 'American', 'American', 'Korean', 'Chinese', 'American', 'French', 'American', 'Chinese', 'American', 'Middle', 'French', 'American', 'American', 'Chinese', 'French', '-', 'American', 'American', 'American', '[American]', 'Chinese', 'French', 'Unknown', 'French', 'American', 'Korean', 'French', 'British', '[Cub', '(', 'American', 'French', 'Japanese', '(Note:', 'American', 'French', 'Chinese', 'Chinese', 'American', 'American', 'American', 'American', 'American', 'American', 'Chinese', 'Korean', 'Mexican', 'Chinese', 'American', 'French', '(no', 'French', 'British', 'Mexican', 'American', 'Chinese', '[homemade', 'American', 'French', 'Chinese', '-', 'Chinese', 'Chinese', 'Seafood', 'French', 'Chinese', 'American', 'American', 'American', 'I', 'American', 'Japanese', 'Italian', '(no', 'Vietnamese', 'French', 'American', 'American', 'American', 'French', 'Italian', 'Chinese', 'American', 'French', 'Chinese', '-', 'British', 'French', '[American]', '[Fish]', '[American]', '(technically', 'Japanese', 'American', 'American', 'French', 'American', 'Italian', 'American', 'Spanish', '-', 'French', 'American', 'Chinese', 'Chinese', 'American', 'Southern', 'various', 'American', 'American', 'American', 'American', 'American', 'American', 'French', 'Chinese', 'French', 'Chinese', 'American', 'American', 'American', 'None', 'French', 'American', '(no', 'Southern', 'German/', 'Middle', 'Italian', '(Not', 'Italian', 'American', 'Chinese', '-', 'Italian', 'American', 'Korean', 'American', 'Chinese', 'French', 'American', '-', 'French', 'Italian', 'German', 'Italian', 'French', 'Italian', 'Japanese', 'Chinese', 'Bosnian', 'Russian', 'Chinese', '[Italian]', 'American', 'French', 'Chinese', 'French', 'French', 'French', 'American', 'American', 'Chinese', 'American', 'Cuban', 'American', 'American', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'American', 'American', 'French', '#', 'American', 'American', 'British', 'Greek', 'French', '(no', 'American', 'French', 'Vietnamese', 'American', 'American', 'American', 'Brazilian', 'French', 'American', 'Chinese', 'Middle', 'Greek', 'French', 'French', 'Japanese', 'British', 'American', 'Indian', 'Middle', 'French', 'German', 'Chinese', 'French', 'Chinese', 'American', 'American', 'American', 'Middle', 'French', 'American', 'American', '(any', 'Southern', 'Italian', 'French', 'Japanese', 'Portuguese', 'French', 'British/English', 'American', 'Chinese', 'Japanese', 'American', 'Greek', 'Mexican', 'American', 'French', 'American', 'Chinese', 'French', 'French', 'American', 'American', 'French', 'American', 'Mexican', 'British', 'Chinese', 'Chinese', 'American', 'American', 'Chinese', 'Russian', 'French', 'French', 'French', 'Chinese', 'American', '(I', 'American', 'Southern', 'Various', '2015', 'British', 'American', 'Japanese', 'Chinese', 'American', 'American', 'American', 'no', 'Italian', 'American', 'American', ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/ethnic_titles_2022_split_1.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## SPLIT 2

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles2
authors=authors2
ids=ids2

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into the most probable cuisine ethnicity: Italian, American, Mexican, French, Chinese, Indian, Japanese, Middle Eastern, etc.\n\n[homemade] hummus I made today #### Middle Eastern\n[Homemade] Beef Shoyu Ramen #### Japanese\n[homemade] curry chicken, rice, & naan #### Indian\n[homemade] Chicken tacos and guacamole #### Mexican\n[Homemade] bacon and artichoke hearts pizza #### Italian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 5.78 seconds
# Estimated time for all batches: 3263.58 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['Chinese', 'Indian', 'French', 'French', 'American', 'Chinese', 'American', 'American', 'Chinese', 'Spanish', 'Asian', 'American', 'British', 'Unknown', 'American', 'American', 'American', 'American', 'American', 'German', 'Italian', 'Italian', 'Filipino', 'American', 'Italian', 'Chinese', 'South', 'ക', 'Chinese', 'American', 'Fruit', 'Mexican', 'Polish', 'American', 'Chinese', 'Indian', 'Chinese', 'Chinese', 'Italian', '[American]', 'Chinese', 'Chinese', 'Chinese', '-', 'American', 'Fruit', 'American', 'Chinese', 'Italian', 'Indian', 'Japanese', 'American', 'American', 'American', 'British', 'Chinese', 'Chinese', 'American', 'Unknown', 'Chinese', 'Greek', 'Chinese', 'Chinese', 'American', 'American', 'French', 'Swedish', 'Mexican', 'French', 'Chinese', 'Spanish', 'American', 'Chinese', 'British', 'German', 'American', 'American', 'Italian', 'French', 'Various', 'Korean', 'American', 'Spanish', '(French)', 'Chinese', 'American', 'Italian', 'European', 'Indian', 'American', 'American', 'Mexican', 'British', 'French', 'French', 'American', 'American', 'Chinese', 'Chinese', 'Chinese', 'American', 'American', 'American', 'French', 'American', 'American', '[Chinese]', 'American', 'Chinese', 'Chinese', 'French', 'American', 'Mexican', 'American', 'German', 'French', 'French', 'American', 'American', 'Italian', '[American]', 'American', 'American', 'Fruit', 'French', 'French', 'Chinese', 'Chinese', 'Italian', 'French', 'Latin', 'British/American', 'Chinese', '(no', 'American', 'Chinese', '(Not', 'French', 'Korean', 'French', 'British', 'American', 'Chinese', 'French', 'American', 'American', 'American', 'American', 'French', 'Chinese', 'French', 'Chinese', '-', 'American', 'Southern', '70%', 'French', 'French', 'Mexican', 'Ukrainian', '(no', 'Chinese', 'Chinese', 'French', 'Italian', 'Chinese', 'Chinese', 'French', 'Chinese', 'American', 'American', '(no', 'Chinese', '-', 'Hawaiian', 'American', 'Italian', 'French', 'American', 'American', 'Peruvian', 'French', 'Italian', 'Chinese', 'French', 'Chinese', 'Vegan', 'Chinese', 'Mexican', 'Australian', 'British/English', 'American', 'American', 'Hawaiian', 'Chinese', 'Chinese', '(This', 'Italian', 'Mexican', 'American', 'British', 'American', 'American', 'American', 'French', 'American', 'American', '-', 'American', 'Mexican', 'Italian', 'American', 'French', 'Chinese', '[Chocolate]', '[Chinese]', 'American', 'Chinese', 'Middle', 'Chinese', '[American]', 'American', 'Caribbean', 'American', 'Chinese', '19th', 'American', 'Middle', 'Chinese', 'Chinese', 'French', 'American', 'American', '-', 'American', 'Japanese', 'French', 'Chinese', 'Mexican', 'American', 'French', 'Chinese', 'Italian', 'Chinese', 'American', 'American', 'American', 'French', 'No', 'American', 'American', 'American', 'French', 'Southern', 'American', 'Chinese', 'Chinese', 'American', 'American', '-', 'Japanese', 'American', 'French', 'Hawaiian', 'I', 'Mexican', 'American', 'American', 'Mexican', 'Japanese', 'Unknown', 'American', 'American', 'Mexican', 'French', 'American', 'British', 'Chinese', 'None', 'American', 'American', 'Chinese', 'Mexican', 'American', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'Chinese', 'American', 'Italian', 'Greek', 'Korean', 'American', 'Chinese', 'British', 'Chinese', '#Fagg', 'American', 'American', 'American', 'Not', 'Italian', 'Italian', 'French', 'British', 'British', 'Indian', 'Middle', 'American', 'American', 'American', 'American', 'American', 'Middle', 'American', '(no', 'Greek', 'Italian', 'American', 'French', 'American', 'American', 'American', 'French', 'Italian', '[American]', 'Chinese', 'Indian', 'American', 'American', 'American', 'American', 'American', 'American', 'American', 'Not', 'French', 'Chinese', 'Vietnamese', 'American', 'British', 'American', 'American', 'French', 'French', 'American', 'Chinese', 'Chinese', 'French', 'Chinese', 'American', 'American', 'American', 'Greek', 'American', 'American', 'American', 'American', 'American' ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/ethnic_titles_2022_split_2.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## SPLIT 3

# %%
from math import ceil
import time
import torch
import gc

# to change in other splits
titles=titles3
authors=authors3
ids=ids3

# Function to calculate token length
def token_length(input_text):
    tokens = tokenizer(input_text, return_tensors="pt").input_ids
    return tokens.shape[-1]

# Set padding token and padding side
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"  # Ensure correct padding for decoder-only architectures

# Defining the input instruction text
instruction_text = "Classify the following titles into the most probable cuisine ethnicity: Italian, American, Mexican, French, Chinese, Indian, Japanese, Middle Eastern, etc.\n\n[homemade] hummus I made today #### Middle Eastern\n[Homemade] Beef Shoyu Ramen #### Japanese\n[homemade] curry chicken, rice, & naan #### Indian\n[homemade] Chicken tacos and guacamole #### Mexican\n[Homemade] bacon and artichoke hearts pizza #### Italian\n"

# Hashtag for classification separation
hashtag = " #### "

# Batch size configuration
batch_size = 50

# Function to process each batch
def process_batch(batch_titles):
    input_texts = [instruction_text + title + hashtag for title in batch_titles]

    # Tokenize the batch with padding and truncation
    encoding = tokenizer(input_texts, return_tensors="pt", padding=True, truncation=True)
    input_ids = encoding.input_ids.to(device)  # Move input_ids to the same device as the model
    attention_mask = encoding.attention_mask.to(device)  # Move attention_mask to the same device

    # Set max_length to the maximum token length in the batch (to avoid generating too many tokens)
    max_lengths = [token_length(input_text) + 3 for input_text in input_texts]
    max_length = max(max_lengths)  # Get the maximum length for generation

    # Generate output from the model
    generated_ids = model.generate(
        input_ids,
        attention_mask=attention_mask,
        max_length=max_length,
        do_sample=True,
        eos_token_id=tokenizer.encode("####")[0],
        pad_token_id=tokenizer.eos_token_id
    )

    # Decode results and classify them
    batch_results = []
    for generated_id in generated_ids:
        generated_text = tokenizer.decode(generated_id, skip_special_tokens=True)

        # Extract the classification from the generated text
        if hashtag in generated_text:
            split_text = generated_text.split(hashtag)
            if len(split_text) > 1 and split_text[-1].strip():  # Check presence of text after "####"
                classification = split_text[-1].split()[0]
            else:
                classification = "unknown"  # Fallback if no classification found
        else:
            classification = "unknown"  # Fallback if "####" not found

        batch_results.append(classification)

    return batch_results

# Divide the titles into batches
num_batches = ceil(len(titles) / batch_size)
results = []

# Start processing batches
for i in range(num_batches):
    start = i * batch_size
    end = min((i + 1) * batch_size, len(titles))
    batch_titles = titles[start:end]

    if i == 0:
        # Process the first batch and estimate time for remaining batches
        start_time = time.time()
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)
        first_batch_time = time.time() - start_time
        average_time = first_batch_time * num_batches
        print(f"First batch time: {first_batch_time:.2f} seconds")
        print(f"Estimated time for all batches: {average_time:.2f} seconds")
    else:
        # Process subsequent batches
        batch_results = process_batch(batch_titles)
        results.extend(batch_results)

    # Clear GPU memory after each batch to avoid memory fragmentation
    torch.cuda.empty_cache()
    gc.collect()

    print(f"Processed batch {i + 1}/{num_batches}")

# Output the final results
print(results)
# Out:
# First batch time: 4.22 seconds
# Estimated time for all batches: 2385.83 seconds
# Processed batch 1/565
# Processed batch 2/565
# Processed batch 3/565
# Processed batch 4/565
# Processed batch 5/565
# Processed batch 6/565
# Processed batch 7/565
# Processed batch 8/565
# Processed batch 9/565
# Processed batch 10/565
# Processed batch 11/565
# Processed batch 12/565
# Processed batch 13/565
# Processed batch 14/565
# Processed batch 15/565
# Processed batch 16/565
# Processed batch 17/565
# Processed batch 18/565
# Processed batch 19/565
# Processed batch 20/565
# Processed batch 21/565
# Processed batch 22/565
# Processed batch 23/565
# Processed batch 24/565
# Processed batch 25/565
# Processed batch 26/565
# Processed batch 27/565
# Processed batch 28/565
# Processed batch 29/565
# Processed batch 30/565
# Processed batch 31/565
# Processed batch 32/565
# Processed batch 33/565
# Processed batch 34/565
# Processed batch 35/565
# Processed batch 36/565
# Processed batch 37/565
# Processed batch 38/565
# Processed batch 39/565
# Processed batch 40/565
# Processed batch 41/565
# Processed batch 42/565
# Processed batch 43/565
# Processed batch 44/565
# Processed batch 45/565
# Processed batch 46/565
# Processed batch 47/565
# Processed batch 48/565
# Processed batch 49/565
# Processed batch 50/565
# Processed batch 51/565
# Processed batch 52/565
# Processed batch 53/565
# Processed batch 54/565
# Processed batch 55/565
# Processed batch 56/565
# Processed batch 57/565
# Processed batch 58/565
# Processed batch 59/565
# Processed batch 60/565
# Processed batch 61/565
# Processed batch 62/565
# Processed batch 63/565
# Processed batch 64/565
# Processed batch 65/565
# Processed batch 66/565
# Processed batch 67/565
# Processed batch 68/565
# Processed batch 69/565
# Processed batch 70/565
# Processed batch 71/565
# Processed batch 72/565
# Processed batch 73/565
# Processed batch 74/565
# Processed batch 75/565
# Processed batch 76/565
# Processed batch 77/565
# Processed batch 78/565
# Processed batch 79/565
# Processed batch 80/565
# Processed batch 81/565
# Processed batch 82/565
# Processed batch 83/565
# Processed batch 84/565
# Processed batch 85/565
# Processed batch 86/565
# Processed batch 87/565
# Processed batch 88/565
# Processed batch 89/565
# Processed batch 90/565
# Processed batch 91/565
# Processed batch 92/565
# Processed batch 93/565
# Processed batch 94/565
# Processed batch 95/565
# Processed batch 96/565
# Processed batch 97/565
# Processed batch 98/565
# Processed batch 99/565
# Processed batch 100/565
# Processed batch 101/565
# Processed batch 102/565
# Processed batch 103/565
# Processed batch 104/565
# Processed batch 105/565
# Processed batch 106/565
# Processed batch 107/565
# Processed batch 108/565
# Processed batch 109/565
# Processed batch 110/565
# Processed batch 111/565
# Processed batch 112/565
# Processed batch 113/565
# Processed batch 114/565
# Processed batch 115/565
# Processed batch 116/565
# Processed batch 117/565
# Processed batch 118/565
# Processed batch 119/565
# Processed batch 120/565
# Processed batch 121/565
# Processed batch 122/565
# Processed batch 123/565
# Processed batch 124/565
# Processed batch 125/565
# Processed batch 126/565
# Processed batch 127/565
# Processed batch 128/565
# Processed batch 129/565
# Processed batch 130/565
# Processed batch 131/565
# Processed batch 132/565
# Processed batch 133/565
# Processed batch 134/565
# Processed batch 135/565
# Processed batch 136/565
# Processed batch 137/565
# Processed batch 138/565
# Processed batch 139/565
# Processed batch 140/565
# Processed batch 141/565
# Processed batch 142/565
# Processed batch 143/565
# Processed batch 144/565
# Processed batch 145/565
# Processed batch 146/565
# Processed batch 147/565
# Processed batch 148/565
# Processed batch 149/565
# Processed batch 150/565
# Processed batch 151/565
# Processed batch 152/565
# Processed batch 153/565
# Processed batch 154/565
# Processed batch 155/565
# Processed batch 156/565
# Processed batch 157/565
# Processed batch 158/565
# Processed batch 159/565
# Processed batch 160/565
# Processed batch 161/565
# Processed batch 162/565
# Processed batch 163/565
# Processed batch 164/565
# Processed batch 165/565
# Processed batch 166/565
# Processed batch 167/565
# Processed batch 168/565
# Processed batch 169/565
# Processed batch 170/565
# Processed batch 171/565
# Processed batch 172/565
# Processed batch 173/565
# Processed batch 174/565
# Processed batch 175/565
# Processed batch 176/565
# Processed batch 177/565
# Processed batch 178/565
# Processed batch 179/565
# Processed batch 180/565
# Processed batch 181/565
# Processed batch 182/565
# Processed batch 183/565
# Processed batch 184/565
# Processed batch 185/565
# Processed batch 186/565
# Processed batch 187/565
# Processed batch 188/565
# Processed batch 189/565
# Processed batch 190/565
# Processed batch 191/565
# Processed batch 192/565
# Processed batch 193/565
# Processed batch 194/565
# Processed batch 195/565
# Processed batch 196/565
# Processed batch 197/565
# Processed batch 198/565
# Processed batch 199/565
# Processed batch 200/565
# Processed batch 201/565
# Processed batch 202/565
# Processed batch 203/565
# Processed batch 204/565
# Processed batch 205/565
# Processed batch 206/565
# Processed batch 207/565
# Processed batch 208/565
# Processed batch 209/565
# Processed batch 210/565
# Processed batch 211/565
# Processed batch 212/565
# Processed batch 213/565
# Processed batch 214/565
# Processed batch 215/565
# Processed batch 216/565
# Processed batch 217/565
# Processed batch 218/565
# Processed batch 219/565
# Processed batch 220/565
# Processed batch 221/565
# Processed batch 222/565
# Processed batch 223/565
# Processed batch 224/565
# Processed batch 225/565
# Processed batch 226/565
# Processed batch 227/565
# Processed batch 228/565
# Processed batch 229/565
# Processed batch 230/565
# Processed batch 231/565
# Processed batch 232/565
# Processed batch 233/565
# Processed batch 234/565
# Processed batch 235/565
# Processed batch 236/565
# Processed batch 237/565
# Processed batch 238/565
# Processed batch 239/565
# Processed batch 240/565
# Processed batch 241/565
# Processed batch 242/565
# Processed batch 243/565
# Processed batch 244/565
# Processed batch 245/565
# Processed batch 246/565
# Processed batch 247/565
# Processed batch 248/565
# Processed batch 249/565
# Processed batch 250/565
# Processed batch 251/565
# Processed batch 252/565
# Processed batch 253/565
# Processed batch 254/565
# Processed batch 255/565
# Processed batch 256/565
# Processed batch 257/565
# Processed batch 258/565
# Processed batch 259/565
# Processed batch 260/565
# Processed batch 261/565
# Processed batch 262/565
# Processed batch 263/565
# Processed batch 264/565
# Processed batch 265/565
# Processed batch 266/565
# Processed batch 267/565
# Processed batch 268/565
# Processed batch 269/565
# Processed batch 270/565
# Processed batch 271/565
# Processed batch 272/565
# Processed batch 273/565
# Processed batch 274/565
# Processed batch 275/565
# Processed batch 276/565
# Processed batch 277/565
# Processed batch 278/565
# Processed batch 279/565
# Processed batch 280/565
# Processed batch 281/565
# Processed batch 282/565
# Processed batch 283/565
# Processed batch 284/565
# Processed batch 285/565
# Processed batch 286/565
# Processed batch 287/565
# Processed batch 288/565
# Processed batch 289/565
# Processed batch 290/565
# Processed batch 291/565
# Processed batch 292/565
# Processed batch 293/565
# Processed batch 294/565
# Processed batch 295/565
# Processed batch 296/565
# Processed batch 297/565
# Processed batch 298/565
# Processed batch 299/565
# Processed batch 300/565
# Processed batch 301/565
# Processed batch 302/565
# Processed batch 303/565
# Processed batch 304/565
# Processed batch 305/565
# Processed batch 306/565
# Processed batch 307/565
# Processed batch 308/565
# Processed batch 309/565
# Processed batch 310/565
# Processed batch 311/565
# Processed batch 312/565
# Processed batch 313/565
# Processed batch 314/565
# Processed batch 315/565
# Processed batch 316/565
# Processed batch 317/565
# Processed batch 318/565
# Processed batch 319/565
# Processed batch 320/565
# Processed batch 321/565
# Processed batch 322/565
# Processed batch 323/565
# Processed batch 324/565
# Processed batch 325/565
# Processed batch 326/565
# Processed batch 327/565
# Processed batch 328/565
# Processed batch 329/565
# Processed batch 330/565
# Processed batch 331/565
# Processed batch 332/565
# Processed batch 333/565
# Processed batch 334/565
# Processed batch 335/565
# Processed batch 336/565
# Processed batch 337/565
# Processed batch 338/565
# Processed batch 339/565
# Processed batch 340/565
# Processed batch 341/565
# Processed batch 342/565
# Processed batch 343/565
# Processed batch 344/565
# Processed batch 345/565
# Processed batch 346/565
# Processed batch 347/565
# Processed batch 348/565
# Processed batch 349/565
# Processed batch 350/565
# Processed batch 351/565
# Processed batch 352/565
# Processed batch 353/565
# Processed batch 354/565
# Processed batch 355/565
# Processed batch 356/565
# Processed batch 357/565
# Processed batch 358/565
# Processed batch 359/565
# Processed batch 360/565
# Processed batch 361/565
# Processed batch 362/565
# Processed batch 363/565
# Processed batch 364/565
# Processed batch 365/565
# Processed batch 366/565
# Processed batch 367/565
# Processed batch 368/565
# Processed batch 369/565
# Processed batch 370/565
# Processed batch 371/565
# Processed batch 372/565
# Processed batch 373/565
# Processed batch 374/565
# Processed batch 375/565
# Processed batch 376/565
# Processed batch 377/565
# Processed batch 378/565
# Processed batch 379/565
# Processed batch 380/565
# Processed batch 381/565
# Processed batch 382/565
# Processed batch 383/565
# Processed batch 384/565
# Processed batch 385/565
# Processed batch 386/565
# Processed batch 387/565
# Processed batch 388/565
# Processed batch 389/565
# Processed batch 390/565
# Processed batch 391/565
# Processed batch 392/565
# Processed batch 393/565
# Processed batch 394/565
# Processed batch 395/565
# Processed batch 396/565
# Processed batch 397/565
# Processed batch 398/565
# Processed batch 399/565
# Processed batch 400/565
# Processed batch 401/565
# Processed batch 402/565
# Processed batch 403/565
# Processed batch 404/565
# Processed batch 405/565
# Processed batch 406/565
# Processed batch 407/565
# Processed batch 408/565
# Processed batch 409/565
# Processed batch 410/565
# Processed batch 411/565
# Processed batch 412/565
# Processed batch 413/565
# Processed batch 414/565
# Processed batch 415/565
# Processed batch 416/565
# Processed batch 417/565
# Processed batch 418/565
# Processed batch 419/565
# Processed batch 420/565
# Processed batch 421/565
# Processed batch 422/565
# Processed batch 423/565
# Processed batch 424/565
# Processed batch 425/565
# Processed batch 426/565
# Processed batch 427/565
# Processed batch 428/565
# Processed batch 429/565
# Processed batch 430/565
# Processed batch 431/565
# Processed batch 432/565
# Processed batch 433/565
# Processed batch 434/565
# Processed batch 435/565
# Processed batch 436/565
# Processed batch 437/565
# Processed batch 438/565
# Processed batch 439/565
# Processed batch 440/565
# Processed batch 441/565
# Processed batch 442/565
# Processed batch 443/565
# Processed batch 444/565
# Processed batch 445/565
# Processed batch 446/565
# Processed batch 447/565
# Processed batch 448/565
# Processed batch 449/565
# Processed batch 450/565
# Processed batch 451/565
# Processed batch 452/565
# Processed batch 453/565
# Processed batch 454/565
# Processed batch 455/565
# Processed batch 456/565
# Processed batch 457/565
# Processed batch 458/565
# Processed batch 459/565
# Processed batch 460/565
# Processed batch 461/565
# Processed batch 462/565
# Processed batch 463/565
# Processed batch 464/565
# Processed batch 465/565
# Processed batch 466/565
# Processed batch 467/565
# Processed batch 468/565
# Processed batch 469/565
# Processed batch 470/565
# Processed batch 471/565
# Processed batch 472/565
# Processed batch 473/565
# Processed batch 474/565
# Processed batch 475/565
# Processed batch 476/565
# Processed batch 477/565
# Processed batch 478/565
# Processed batch 479/565
# Processed batch 480/565
# Processed batch 481/565
# Processed batch 482/565
# Processed batch 483/565
# Processed batch 484/565
# Processed batch 485/565
# Processed batch 486/565
# Processed batch 487/565
# Processed batch 488/565
# Processed batch 489/565
# Processed batch 490/565
# Processed batch 491/565
# Processed batch 492/565
# Processed batch 493/565
# Processed batch 494/565
# Processed batch 495/565
# Processed batch 496/565
# Processed batch 497/565
# Processed batch 498/565
# Processed batch 499/565
# Processed batch 500/565
# Processed batch 501/565
# Processed batch 502/565
# Processed batch 503/565
# Processed batch 504/565
# Processed batch 505/565
# Processed batch 506/565
# Processed batch 507/565
# Processed batch 508/565
# Processed batch 509/565
# Processed batch 510/565
# Processed batch 511/565
# Processed batch 512/565
# Processed batch 513/565
# Processed batch 514/565
# Processed batch 515/565
# Processed batch 516/565
# Processed batch 517/565
# Processed batch 518/565
# Processed batch 519/565
# Processed batch 520/565
# Processed batch 521/565
# Processed batch 522/565
# Processed batch 523/565
# Processed batch 524/565
# Processed batch 525/565
# Processed batch 526/565
# Processed batch 527/565
# Processed batch 528/565
# Processed batch 529/565
# Processed batch 530/565
# Processed batch 531/565
# Processed batch 532/565
# Processed batch 533/565
# Processed batch 534/565
# Processed batch 535/565
# Processed batch 536/565
# Processed batch 537/565
# Processed batch 538/565
# Processed batch 539/565
# Processed batch 540/565
# Processed batch 541/565
# Processed batch 542/565
# Processed batch 543/565
# Processed batch 544/565
# Processed batch 545/565
# Processed batch 546/565
# Processed batch 547/565
# Processed batch 548/565
# Processed batch 549/565
# Processed batch 550/565
# Processed batch 551/565
# Processed batch 552/565
# Processed batch 553/565
# Processed batch 554/565
# Processed batch 555/565
# Processed batch 556/565
# Processed batch 557/565
# Processed batch 558/565
# Processed batch 559/565
# Processed batch 560/565
# Processed batch 561/565
# Processed batch 562/565
# Processed batch 563/565
# Processed batch 564/565
# Processed batch 565/565
# ['French', 'American', 'Chinese', 'American', 'American', 'Italian', 'Japanese', 'French', 'American', 'Chinese', 'Greek', 'Japanese', 'Indian', '-', 'American', 'American', '[Italian]', 'American', 'Chinese', 'American', 'American', 'American', 'American', '[American]', '(French)', 'American', 'Italian', 'American', 'Italian', 'Italian', 'American', 'Italian', 'Italian', 'Middle', 'Italian', 'American', '(Note:', 'American', 'French', 'American', 'Mexican', 'Japanese', 'French', 'French', 'Italian', 'Italian', 'American', 'Japanese', 'American', 'American', 'French', 'Southeast', 'Italian', 'Chinese', 'American', '[Chinese]', 'Chinese', 'American', 'American', 'American', 'American', 'Italian', 'Chinese', 'British', 'Italian', 'American', 'American', 'Vegetarian', 'French', 'American', 'Mexican', 'Mexican', 'American', 'Chinese', 'Chinese', 'Chinese', 'American', 'Chinese', 'American', 'Greek', 'American', 'Hawaiian', 'Korean', 'American', 'Greek', 'Fruit-based', '(no', '(Nutella', 'Indian', 'British/', 'Chinese', 'American', 'British', 'Japanese', 'American', 'American', 'American', 'American', 'French', 'Chinese', 'American', 'American', 'American', 'French', 'Japanese', 'Chinese', 'French', '#', 'Chinese', 'American', 'Greek', 'Chinese', 'Korean', 'American', 'British/', 'French', 'Chinese', 'African', 'American', 'French', 'Greek', 'American', 'American', 'Dominican', 'Turkish', 'Chinese', 'Chinese', 'Mexican', 'French', 'French', 'American', 'American', 'Japanese', 'Indian', 'American', '[Canadian]', 'Japanese', 'Chinese', 'Italian', 'American', 'American', 'Unknown', 'Mexican', 'Chinese', 'American', 'Fruit-based', 'Chinese', 'American', 'Indian', 'British/Indian', 'Japanese', 'Hawaiian', 'Japanese', '[homemade', 'American', 'French', 'French', 'Spanish', 'American', '[American]', '(This', 'Vietnamese', 'American', 'Chinese', 'Italian', 'Chinese', 'Chinese', 'American', 'American', 'Chinese', 'American', 'Chinese', 'Italian', 'Italian', 'American', 'Middle', 'Italian', 'Chinese', 'Chinese', 'French', 'American', 'Italian', 'Italian', 'American', 'American', 'Italian', 'American', 'American', 'American', 'Asian', 'American', '-', 'American', 'American', 'American', 'American', 'French', 'Chinese', 'American', 'Italian', 'Chinese', 'American', 'Mexican', 'French', 'American', 'American', 'American', 'American', 'Chinese', 'American', 'American', 'Italian', 'American', 'American', 'French', 'French', 'French', 'American', 'American', 'Mexican', 'American', 'Middle', 'Japanese', 'Italian', '(no', 'American', 'American', 'American', 'Mexican', 'American', 'Chinese', 'Chinese', '-', 'American', 'Chinese', 'American', 'Chinese', 'American', 'Chinese', 'Greek', 'Chinese', 'American', 'Italian', 'Mexican', 'French', 'American', 'American', 'American', 'Chinese', 'Italian', '[Unknown]', 'Mexican', 'American', 'American', 'American', '[no', '[Spanish]', 'German', 'American', 'Italian', 'French', 'Mexican', 'American', 'American', 'Unknown', 'Chinese', 'American', '[American]', '[no', 'American', '[American]', 'American', 'American', 'Chinese', 'Korean', 'American', '[Chinese]', 'Japanese', 'Chinese', 'Unknown', '[Greek]', 'British', 'American', '(no', 'Indian', 'Chinese', 'French', 'Korean', 'Middle', 'American', 'Italian', '[German]', 'American', 'American', 'French', 'Japanese', 'American', 'Chinese', 'American', 'American', 'French', 'American', 'Chinese', 'American', 'Chinese', 'American', 'Chinese', 'Chinese', 'American', 'American', 'American', 'Mexican', 'Japanese', 'AI-generated', 'French', 'American', 'Southern', 'Chinese', 'American', 'Chinese', 'Chinese', 'German', 'Japanese', 'American', 'Chinese', 'Chinese', 'Banglades', 'Mexican', 'Chinese', 'American', 'Fruit', 'Chinese', '(no', 'Chinese', 'BBQ', 'French', 'American', 'American', 'American', 'French', 'British', '#', 'Chinese', 'German', 'Chinese', 'Chinese', 'American', 'American', 'Chinese', 'American', 'Mexican', '-', '(no', 'Chinese', 'American', 'Italian', 'Ita ...

# %%
# writing the results into a csv file

import csv
from google.colab import drive

drive.mount('/content/gdrive')

list1 = authors
list2 = results
list3 = ids

# Nome del file CSV
file_csv = r"/content/gdrive/MyDrive/dati_sna/ethnic_titles_2022_split_3.csv"

# write on the csv
with open(file_csv, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["author", "classification", "id"])
    i=0
    # writing rows
    for element1, element2, element3 in zip(list1, list2, list3):
        writer.writerow([element1, element2, element3])
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## Split Combining

# %%
import pandas as pd

# Percorsi dei file CSV
dati_sna_path = "/content/gdrive/MyDrive/dati_sna/"
file_names = [
    "ethnic_titles_2022_split_1.csv",
    "ethnic_titles_2022_split_2.csv",
    "ethnic_titles_2022_split_3.csv"
]

# Leggi e unisci i file
combined_df = pd.concat([pd.read_csv(dati_sna_path + file) for file in file_names])

# Salva il file unito
output_file = dati_sna_path + "ethnic_titles_2022.csv"
combined_df.to_csv(output_file, index=False)

print(f"File unito salvato in: {output_file}")
# Out:
# File unito salvato in: /content/gdrive/MyDrive/dati_sna/ethnic_titles_2022.csv
